# %% [markdown]
# # Méthodes d'optimisation: Contrôle continu (CC)

# %% [markdown]
# ## Librairies

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

# Autres librairies à importer en fonction
# des modèles et fonctionalités que vous utilisez

from sklearn.metrics import classification_report

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Dataset

# %%
df = pd.read_csv("LifeExpectancyData.csv")

# %%
df
# Out:
#           Country  Year      Status  Life_Expectancy  Adult_Mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 1644     Zimbabwe  2004  Developing             44.3            723.0
# 1645     Zimbabwe  2003  Developing             44.5            715.0
# 1646     Zimbabwe  2002  Developing             44.8             73.0
# 1647     Zimbabwe  2001  Developing             45.3            686.0
# 1648     Zimbabwe  2000  Developing             46.0            665.0
#
#       Infant_Deaths  Alcohol  Percentage_Expenditure  Hepatitis_B  Measles  \
# ...

# %%
df.shape
# Out:
# (1649, 22)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Exercice 1
#
# **Problème de regression**
#
# Implémetez un ou plusieurs modèles de machine learning permettant de **prédire la variable continue `Life_Expectancy`** du dataset donné.
#
# Essayez de rendre un notebook propre, avec du texte explicatif et du code commenté.

# %% [markdown]
# ## Exercice 2
#
# **Problème de classification**
#
# Implémetez un ou plusieurs modèles de machine learning permettant de **prédire la variable discrète `Status`** du dataset donné.
#
# Essayez de rendre un notebook propre, avec du texte explicatif et du code commenté.
